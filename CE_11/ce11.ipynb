# %%
import numpy
#circular towns, hw2 has stuff for the area

# %%
def normalize_longitude(lon: float) ->float:
    """ Normalize a longitude value to be in a range of (-180, 180)."""
    if lon > 180:
        return lon - 360
    elif lon < -180:
        return lon + 360
    else:
        return lon

# %%
def test_normalized_longitude():
    expected = {
        360: 0, 
        -190: 170,
    }
    actual= dict()
    
    for val in expected:
        actual_longitude= normalize_longitude(val)
        actual[val]= actual_longitude
        
        
    
    assert actual == expected

# %%
test_normalized_longitude()

# %%
def area_m2(polygon, crs):
    source_crs = pyproj.CRS(f"{crs}")
    target_crs = pyproj.CRS('EPSG:6933')
    project= pyproj.Transformer.from_crs(source_crs, target_crs).transform
    projected_polygon= transform(project, polygon)
    return projected_polygon.area

# %%
def test_area(self):
    poly = Polygon([(0,0),(1,0),(1,1),(0,1),(0,0)])
    crs = "EPSG:4326"
    result= area_m2(poly,crs)
    expected_min = 12_000_000_000
    expected_max = 13_000_000_000
    self.assertIsInstance(result, float)
    self.assertTrue(expected_min < result < expected_max, f"Expected area, but got {result}")
